# %% [markdown]
# **My Jupyter Notebook on IBM Watson Studio**

# %% [markdown]
# **Alana Olivieri**
# > Student

# %% [markdown]
# *I am interested in becoming a data scientist because I love predicting data through machine learning. The invention of AI is equivalent to inventing electricity in the 20th century. I want to be able to contribute in this field for the benefit of humanity.*

# %% [markdown]
# The code represented below calls the iris dataset and plots a pair plot according to the species of the flowers in the dataset using the help of the seaborn library.

# %%
import seaborn as sns

# %%
df = sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df, hue="species")

# %% [markdown]
# Hence, I have performed basic visualization in Jupyter Notebook.
# ---
# As required the code is kept simple for the purpose of the project. Here is a list species of each flower
# 1.   Setosa
# 2.   Virginica
# 3.   Versicolor
#
# The seaborn library can be visited at this link: [https://seaborn.pydata.org/index.html](https://)
#
# The images of all three species are displayed below
# ![image.png](data:image/png;base64,...)
